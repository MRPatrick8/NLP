# %% [markdown]
# <a href="https://colab.research.google.com/github/MRPatrick8/NLP/blob/main/Week%204/EasyNMT.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install -U easynmt
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
from easynmt import EasyNMT

# %%
model = EasyNMT('opus-mt')

# %%
sentences=['Jesus is alive',
           'Hands on projects is our priority',
           "I don't have anything",
           "It is  what is!:legend Balise said",
           "I don't have anything to give you baby"]

# %%
translation_fr = model.translate(sentences,target_lang='fr')
translation_kin = model.translate(sentences,target_lang='rw')
translation_ch = model.translate(sentences,target_lang='zh')
# Out:
# /usr/local/lib/python3.7/dist-packages/transformers/models/marian/tokenization_marian.py:194: UserWarning: Recommended: pip install sacremoses.
#   warnings.warn("Recommended: pip install sacremoses.")
# /usr/local/lib/python3.7/dist-packages/transformers/generation_utils.py:1364: UserWarning: Neither `max_length` nor `max_new_tokens` has been set, `max_length` will default to 512 (`self.config.max_length`). Controlling `max_length` via the config is deprecated and `max_length` will be removed from the config in v5 of Transformers -- we recommend using `max_new_tokens` to control the maximum length of the generation.
#   UserWarning,

# %%
translation_ch
# Out:
# ['耶稣还活着', '手放在项目上是我们的优先事项', '我什么都没有', '就是这样!@legend Balise说:', '我没有东西给你,宝贝']

# %%
import json
with open('/content/languages.json','r+')as file_lang:
  content = file_lang.read()
languages_json = json.loads(content)

# %%
languages_json
# Out:
# [{'code': 'ab', 'name': 'Abkhaz'},
#  {'code': 'aa', 'name': 'Afar'},
#  {'code': 'af', 'name': 'Afrikaans'},
#  {'code': 'ak', 'name': 'Akan'},
#  {'code': 'sq', 'name': 'Albanian'},
#  {'code': 'am', 'name': 'Amharic'},
#  {'code': 'ar', 'name': 'Arabic'},
#  {'code': 'an', 'name': 'Aragonese'},
#  {'code': 'hy', 'name': 'Armenian'},
#  {'code': 'as', 'name': 'Assamese'},
#  {'code': 'av', 'name': 'Avaric'},
#  {'code': 'ae', 'name': 'Avestan'},
#  {'code': 'ay', 'name': 'Aymara'},
#  {'code': 'az', 'name': 'Azerbaijani'},
#  {'code': 'bm', 'name': 'Bambara'},
#  {'code': 'ba', 'name': 'Bashkir'},
#  {'code': 'eu', 'name': 'Basque'},
#  {'code': 'be', 'name': 'Belarusian'},
#  {'code': 'bn', 'name': 'Bengali; Bangla'},
#  {'code': 'bh', 'name': 'Bihari'},
#  {'code': 'bi', 'name': 'Bislama'},
#  {'code': 'bs', 'name': 'Bosnian'},
#  {'code': 'br', 'name': 'Breton'},
#  {'code': 'bg', 'name': 'Bulgarian'},
#  {'code': 'my', 'name': 'Burmese'},
# ...

# %%
languages_json[0]['code']
# Out:
# 'ab'

# %%
from urllib.error import HTTPError

# %%
for codes in languages_json[50:80]:
  code =  codes['code']
  try:
    lang = model.translate(sentences,target_lang=code)
  except:
    pass
# Out:
# WARNING:easynmt.EasyNMT:Exception: Helsinki-NLP/opus-mt-en-ka is not a local folder and is not a valid model identifier listed on 'https://huggingface.co/models'
# If this is a private repository, make sure to pass a token having permission to this repo with `use_auth_token` or log in with `huggingface-cli login` and pass `use_auth_token=True`.
# WARNING:easynmt.EasyNMT:Exception: Helsinki-NLP/opus-mt-en-gn is not a local folder and is not a valid model identifier listed on 'https://huggingface.co/models'
# If this is a private repository, make sure to pass a token having permission to this repo with `use_auth_token` or log in with `huggingface-cli login` and pass `use_auth_token=True`.
# WARNING:easynmt.EasyNMT:Exception: Helsinki-NLP/opus-mt-en-gu is not a local folder and is not a valid model identifier listed on 'https://huggingface.co/models'
# ...

# %%
import pandas as pd
df = pd.DataFrame()
data =pd.DataFrame()

# %%
df['English'] =sentences

# %%
df
# Out:
#                                   English
# 0                          Jesus is alive
# 1       Hands on projects is our priority
# 2                   I don't have anything
# 3      It is  what is!:legend Balise said
# 4  I don't have anything to give you baby

# %%
for codes in languages_json[50:80]:
  code =  codes['code']
  try:
    df[code] = model.translate(df['English'],source_lang='en', target_lang=code)
  except:
    pass
# Out:
# /usr/local/lib/python3.7/dist-packages/transformers/models/marian/tokenization_marian.py:194: UserWarning: Recommended: pip install sacremoses.
#   warnings.warn("Recommended: pip install sacremoses.")
# /usr/local/lib/python3.7/dist-packages/transformers/generation_utils.py:1364: UserWarning: Neither `max_length` nor `max_new_tokens` has been set, `max_length` will default to 512 (`self.config.max_length`). Controlling `max_length` via the config is deprecated and `max_length` will be removed from the config in v5 of Transformers -- we recommend using `max_new_tokens` to control the maximum length of the generation.
#   UserWarning,

# %%
df
# Out:
#                                   English  \
# 0                          Jesus is alive
# 1       Hands on projects is our priority
# 2                   I don't have anything
# 3      It is  what is!:legend Balise said
# 4  I don't have anything to give you baby
#
#                                                de  \
# 0                                      Jesus lebt
# 1  Die Hand auf die Projekte ist unsere Priorität
# 2                                Ich habe nichts.
# 3           Es ist, was ist!:Legend Balise sagte:
# 4                Ich habe dir nichts zu schenken.
#
#                                                el  \
# 0                        Ο Ιησούς είναι ζωντανός.
# 1  Τα χέρια στα σχέδια είναι η προτεραιότητά μας.
# 2                                 Δεν έχω τίποτα.
# 3      Είναι αυτό που είναι!:Ο θρύλος Μπαλίς είπε
# 4                Δεν έχω τίποτα να σου δώσω μωρό.
#
#                                                   ht  \
# ...

# %%
kinya = [
    "Naraye mpinga",
    "urugendo rwiza",
    "Gerayo amahoro",
    "Nyirabakangaza ngo mutahe",
    "naraye ndose!"
]

# %%
data['Kinya']= kinya

# %%
for langs in languages_json[50:80]:
  lang =  langs['code']
  try:
    df[lang] = model.translate(data['kinya'], target_lang=code)
  except:
    pass

# %%
data
# Out:
#                        Kinya
# 0              Naraye mpinga
# 1             urugendo rwiza
# 2             Gerayo amahoro
# 3  Nyirabakangaza ngo mutahe
# 4              naraye ndose!
